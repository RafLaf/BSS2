# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
LL=np.load('LL6.npy',allow_pickle=True)
cond=np.load('conds.npy',allow_pickle=True)
cur=np.load('cur.npy',allow_pickle=True)
time=np.load('times.npy',allow_pickle=True)

# %%
time
# Out:
# array([0.000416, 0.000448, 0.00048 , ..., 0.099384, 0.099424, 0.099456])

# %%
cond
# Out:
# array([   1.   ,  125.875,  250.75 ,  375.625,  500.5  ,  625.375,
#         750.25 ,  875.125, 1000.   ])

# %%
plt.plot(time*10000,LL[5,-1])
plt.xlim((0,20))
# Out:
# (0.0, 20.0)

# %%
def getfreq(data,thres):
    data2=data-thres
    dif=data2[1:]*data2[:-1]
    return np.where(dif<0)[0].size/2

# %%
Lfreq=[getfreq(LL[i,5],400) for i in range(9)]

# %%
plt.scatter(1,30)
for j in range (9):
    plt.plot(cur,[getfreq(LL[i,j],400) for i in range(9)],'--.',label=str(cond[j]))
plt.legend()
plt.xlabel("Biological current (nA)")
plt.ylabel('Firing rate (Hz)')
# Out:
# Text(0, 0.5, 'Firing rate (Hz)')

# %%
nspikestep=np.load("nspikestep.npy",allow_pickle=True)
step=np.load("steps.npy",allow_pickle=True)

# %%
cur[6]
# Out:
# 1.125

# %%
plt.scatter(1,30)
plt.plot(step,nspikestep,label='PNM')
for j in range (0,9,2):
    plt.plot(cur,[getfreq(LL[i,j],400) for i in range(9)],'-.',label=str(cond[j]))
plt.legend()
plt.xlabel("Biological current (nA)")
plt.ylabel('Firing rate (Hz)')
plt.xlim((0,2))
plt.ylim((0,70))
# Out:
# (0.0, 70.0)
