# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
LL=np.load('LL.npy',allow_pickle=True)
cond=np.load('conds.npy',allow_pickle=True)
cur=np.load('cur.npy',allow_pickle=True)
times=np.load('times.npy',allow_pickle=True)
LL2=np.load('LL2.npy',allow_pickle=True)
LL3=np.load('LL3.npy',allow_pickle=True)
LL363=np.load('LL363.npy',allow_pickle=True)
LL4=np.load('LL4.npy',allow_pickle=True)
cur4=np.load('cur4.npy',allow_pickle=True)

# %%
LL.shape
# Out:
# (5, 5)

# %%
plt.plot(LL[4,2])

# %%
plt.plot(LL2[4,3])

# %%
plt.plot(LL3[4,1])

# %%
plt.plot(LL363[2,4])

# %%
def getfreq(data,thres):
    data2=data-thres
    dif=data2[1:]*data2[:-1]
    return np.where(dif<0)[0].size/2

# %%
getfreq(LL4[4,4],400)
# Out:
# 35.0

# %%
plt.plot(LL4[4,4])

# %%
Lfreq=[getfreq(LL4[2,i],400) for i in range(5)]

# %%
plt.plot(cond,Lfreq)
